# %% [markdown]
# ### 1. Write a Python Program to implement your own myreduce() function which works exactly like Python's built-in function reduce()

# %%
from functools import reduce

# %%
def myreduce(func,seq):
    output=seq[0] 
    a=seq[-1]
    for i in seq[1:]:
             if i!=a:
                output=func(output,i)
                
    return output

# %%
list1=[1,2,3,4,5,6]

# %%
reduce(lambda x,y:y-x , list1)
# Out:
# 3

# %%
myreduce(lambda x,y:y-x , list1)
# Out:
# 4

# %% [markdown]
# ## 1.2 Write a Python program to implement your own myfilter() function which works exactly like Python's built-in function filter()

# %%
def myfilter(func,seq):
        l1=[]
        for i in seq:
            if func(i)==True:
                l1.append(i)
            else:
                pass
        return l1

# %%
l2=[2,3,5,4,6,78,49,30]

# %%
f_v=myfilter(lambda x:x%2==0,l2)
list(f_v)
# Out:
# [2, 4, 6, 78, 30]

# %% [markdown]
# ## 2. Implement List comprehensions to produce the following lists.
# ## Write List comprehensions to produce the following Lists

# %% [markdown]
# **2.1 ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']**

# %%
l1=['x','y','z']

[i*j for i in l1 for j in range(1,5)]
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %% [markdown]
# **2.2 ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']**

# %%
[i*j for j in range(1,5) for i in l1]
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %% [markdown]
# **2.3 [[2], [3], [4], [3], [4], [5], [4], [5], [6]] [[2, 3, 4, 5], [3, 4, 5, 6],
# [4, 5, 6, 7], [5, 6, 7, 8]]**

# %%
print([[i+j] for i in range(2,5) for j in range(0,3)],[[a for a in range(2,9)][i:i+4] for i in range(0,4)] )
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]] [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %% [markdown]
# **2.4 [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]**

# %%
[(i,j) for j in range(1,4) for i in range(1,4)]
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
